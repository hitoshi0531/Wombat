# %% [markdown]
# ## 1. Load Dataset

# %%
#import pnadas and numpy
import pandas as pd
import numpy as np

# %%
#Load the dataset into dataframe
df_toilet = pd.read_csv('../data/raw/toiletmapexport_230301_074429.csv')

# %%
#Get the header of the dataframe
df_toilet.head()
# Out:
#    FacilityID                                  URL                  Name  \
# 0           1  https://toiletmap.gov.au/facility/1   Sandy Beach Reserve
# 1           2  https://toiletmap.gov.au/facility/2         Point Reserve
# 2           3  https://toiletmap.gov.au/facility/3  Success Hill Reserve
# 3           4  https://toiletmap.gov.au/facility/4       Jubilee Reserve
# 4           5  https://toiletmap.gov.au/facility/5      Ashfield Reserve
#
#       FacilityType            Address1        Town State AddressNote  \
# 0  Park or reserve           West Road  Bassendean    WA         NaN
# 1  Park or reserve          North Road  Bassendean    WA         NaN
# 2  Park or reserve  Off Seventh Avenue  Bassendean    WA         NaN
# 3  Park or reserve       Robinson Road   Eden Hill    WA         NaN
# 4  Park or reserve      Guildford Road    Ashfield    WA         NaN
#
#     Latitude   Longitude  ...  Ambulant  Accessible LHTransfer  RHTransfer  \
# ...

# %%
df_toilet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22731 entries, 0 to 22730
# Data columns (total 47 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FacilityID         22731 non-null  int64
#  1   URL                22731 non-null  object
#  2   Name               22731 non-null  object
#  3   FacilityType       22731 non-null  object
#  4   Address1           22722 non-null  object
#  5   Town               22731 non-null  object
#  6   State              22731 non-null  object
#  7   AddressNote        1707 non-null   object
#  8   Latitude           22731 non-null  float64
#  9   Longitude          22731 non-null  float64
#  10  Parking            22731 non-null  bool
#  11  ParkingAccessible  22731 non-null  bool
#  12  ParkingNote        1551 non-null   object
#  13  KeyRequired        22731 non-null  bool
#  14  MLAK24             22731 non-null  bool
#  15  MLAKAfterHours     22731 non-null  bool
# ...

# %%
df_toilet.describe()
# Out:
#          FacilityID      Latitude     Longitude
# count  22731.000000  22731.000000  22731.000000
# mean   27898.105583    -32.690716    143.957268
# std    21435.531153      5.529485     10.803019
# min        1.000000    -43.582777    113.410065
# 25%     7631.500000    -36.700480    143.257954
# 50%    18804.000000    -33.852372    146.949642
# 75%    49476.000000    -29.960936    151.104364
# max    60820.000000    -10.570186    153.628820

# %%
df_toilet.hist(figsize = (20,20))
# Out:
# array([[<AxesSubplot: title={'center': 'FacilityID'}>,
#         <AxesSubplot: title={'center': 'Latitude'}>],
#        [<AxesSubplot: title={'center': 'Longitude'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
pip install ipympl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Identify missing values
print("Count of missing values:", df_toilet.isnull().sum())
# Out:
# Count of missing values: FacilityID               0
# URL                      0
# Name                     0
# FacilityType             0
# Address1                 9
# Town                     0
# State                    0
# AddressNote          21024
# Latitude                 0
# Longitude                0
# Parking                  0
# ParkingAccessible        0
# ParkingNote          21180
# KeyRequired              0
# MLAK24                   0
# MLAKAfterHours           0
# PaymentRequired          0
# AccessNote           20995
# AdultChange              0
# ChangingPlaces           0
# BYOSling                 0
# ACShower                 0
# ACMLAK                   0
# AdultChangeNote      22667
# BabyChange               0
# BabyCareRoom             0
# BabyChangeNote       22614
# DumpPoint                0
# DPWashout                0
# DPAfterHours             0
# DumpPointNote        22504
# OpeningHours             0
# OpeningHoursNote     19274
# ...

# %% [markdown]
# **As Toilet Searching Function does not need Machine Learning process, data exploration terminates here**

# %% [markdown]
# ## 2. FastAPI
